# %%
from data_loader import DataLoader
from scipy import interpolate
from scipy.interpolate import CubicSpline, PchipInterpolator, UnivariateSpline
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt

# %%
x = [0,1,2,3]
y = [0, 10, 15, 16]
x_new = [0, 2,4,6,8,10,12,14, 50]

f = CubicSpline(x, y, bc_type='not-a-knot')
y_extrapolated = f(x_new)
print(y_extrapolated)
# Out:
# [ 0. 15. 14.  5. -4. -5. 10. 49.]

# %%
plt.plot(x_new, y_extrapolated)
plt.plot(x,y, 'o')
plt.show()
